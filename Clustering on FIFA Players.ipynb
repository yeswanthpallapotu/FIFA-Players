# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#loading Complete Dataset
pd.set_option('display.max_columns', 500)
full_df=pd.read_csv("D:\Excel sheets\FullData.csv")
full_df.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    Height Weight Preffered_Foot  Birth_Date  Age Preffered_Position  \
# ...

# %%
# Returns an object with all of the column headers
full_df.columns
# Out:
# Index(['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club',
#        'Club_Position', 'Club_Kit', 'Club_Joining', 'Contract_Expiry',
#        'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date', 'Age',
#        'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves',
#        'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes'],
#       dtype='object')

# %%
# Returns number of rows and columns of the dataset
full_df.shape
# Out:
# (17588, 53)

# %%
# Returns basic information on all columns
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17588 entries, 0 to 17587
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                17588 non-null  object
#  1   Nationality         17588 non-null  object
#  2   National_Position   1075 non-null   object
#  3   National_Kit        1075 non-null   float64
#  4   Club                17588 non-null  object
#  5   Club_Position       17587 non-null  object
#  6   Club_Kit            17587 non-null  float64
#  7   Club_Joining        17587 non-null  object
#  8   Contract_Expiry     17587 non-null  float64
#  9   Rating              17588 non-null  int64
#  10  Height              17588 non-null  object
#  11  Weight              17588 non-null  object
#  12  Preffered_Foot      17588 non-null  object
#  13  Birth_Date          17588 non-null  object
#  14  Age                 17588 non-null  int64
# ...

# %%
# Returns true for a column having null values, else false
full_df.isnull().any()
# Out:
# Name                  False
# Nationality           False
# National_Position      True
# National_Kit           True
# Club                  False
# Club_Position          True
# Club_Kit               True
# Club_Joining           True
# Contract_Expiry        True
# Rating                False
# Height                False
# Weight                False
# Preffered_Foot        False
# Birth_Date            False
# Age                   False
# Preffered_Position    False
# Work_Rate             False
# Weak_foot             False
# Skill_Moves           False
# Ball_Control          False
# Dribbling             False
# Marking               False
# Sliding_Tackle        False
# Standing_Tackle       False
# Aggression            False
# Reactions             False
# Attacking_Position    False
# Interceptions         False
# Vision                False
# Composure             False
# Crossing              False
# Short_Pass            False
# Long_Pass             False
# ...

# %%
# Returns basic statistics on numeric column
full_df.describe().T
# Out:
#                       count         mean        std     min     25%     50%  \
# National_Kit         1075.0    12.219535   6.933187     1.0     6.0    12.0
# Club_Kit            17587.0    21.294536  19.163741     1.0     9.0    18.0
# Contract_Expiry     17587.0  2018.899414   1.698787  2017.0  2017.0  2019.0
# Rating              17588.0    66.166193   7.083012    45.0    62.0    66.0
# Age                 17588.0    25.460314   4.680217    17.0    22.0    25.0
# Weak_foot           17588.0     2.934103   0.655927     1.0     3.0     3.0
# Skill_Moves         17588.0     2.303161   0.746156     1.0     2.0     2.0
# Ball_Control        17588.0    57.972766  16.834779     5.0    53.0    63.0
# Dribbling           17588.0    54.802877  18.913857     4.0    47.0    60.0
# Marking             17588.0    44.230327  21.561703     3.0    22.0    48.0
# Sliding_Tackle      17588.0    45.565499  21.515179     5.0    23.0    51.0
# ...

# %%
#Creating new dataset with the coumns we'll be using
df=full_df.loc[:,"Weak_foot":"GK_Reflexes"]

# %%
len(full_df.Club_Position.unique())
# Out:
# 30

# %%
df.head()
# Out:
#    Weak_foot  Skill_Moves  Ball_Control  Dribbling  Marking  Sliding_Tackle  \
# 0          4            5            93         92       22              23
# 1          4            4            95         97       13              26
# 2          5            5            95         96       21              33
# 3          4            4            91         86       30              38
# 4          4            1            48         30       10              11
#
#    Standing_Tackle  Aggression  Reactions  Attacking_Position  Interceptions  \
# 0               31          63         96                  94             29
# 1               28          48         95                  93             22
# 2               24          56         88                  90             36
# 3               45          78         93                  92             41
# 4               10          29         85                  12             30
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17588 entries, 0 to 17587
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Weak_foot           17588 non-null  int64
#  1   Skill_Moves         17588 non-null  int64
#  2   Ball_Control        17588 non-null  int64
#  3   Dribbling           17588 non-null  int64
#  4   Marking             17588 non-null  int64
#  5   Sliding_Tackle      17588 non-null  int64
#  6   Standing_Tackle     17588 non-null  int64
#  7   Aggression          17588 non-null  int64
#  8   Reactions           17588 non-null  int64
#  9   Attacking_Position  17588 non-null  int64
#  10  Interceptions       17588 non-null  int64
#  11  Vision              17588 non-null  int64
#  12  Composure           17588 non-null  int64
#  13  Crossing            17588 non-null  int64
#  14  Short_Pass          17588 non-null  int64
#  15  Long_Pass           17588 non-null  int64
# ...

# %%
#Importing Kmeans for clustering & fitting to df
from sklearn.cluster import KMeans
kmeans_model= KMeans(n_clusters=4,random_state=1)
kmeans_model.fit(df)
labels=kmeans_model.labels_
labels
# Out:
# array([0, 0, 0, ..., 3, 2, 2])

# %%
# Imorting and using PCA 
from sklearn.decomposition import PCA
pca=PCA(2)
pca_df=pca.fit_transform(df)

# %%
pca_df
# Out:
# array([[-121.71000208,  -90.68017839],
#        [-118.56880801, -108.40577922],
#        [-105.58987511,  -92.62893358],
#        ...,
#        [  38.79050421,   -5.52694558],
#        [ 174.34881902,  -13.82922745],
#        [ 179.73163555,   -4.53985297]])

# %%
# Plotting results
col=sns.color_palette("muted",n_colors=4)
sns.set_style("white")
sns.scatterplot(x=pca_df[:,0],y=pca_df[:,1],hue=labels,palette=col)

# %%
#checking all the positions
full_df.Club_Position.unique()
# Out:
# array(['LW', 'RW', 'ST', 'GK', 'Sub', 'RCM', 'CAM', 'LCB', 'LCM', 'RS',
#        'RB', 'RCB', 'LM', 'LDM', 'RM', 'LB', 'CDM', 'RDM', 'LF', 'CB',
#        'LAM', 'Res', 'CM', 'LS', 'RF', 'RWB', 'RAM', 'LWB', nan, 'CF'],
#       dtype=object)

# %%
#Forwards

Cristiano_Ronaldo=df.loc[full_df["Name"]=="Cristiano Ronaldo"].values.tolist() #LW (Left Winger)

Lionel_Messi=df.loc[full_df["Name"]=="Lionel Messi"].values.tolist()       #RW (Right Winger)

# %%
#Mid-Feilders

Mesut_Özil = df.loc[full_df["Name"]=="Mesut Özil"].values.tolist() #CAM (Center Attacking Midfeilder)

Sergio_Busquets =df.loc[full_df["Name"]=="Sergio Busquets"].values.tolist() #CDM (Center Defending Midfeilder)

# %%
#GoalKeepers

Manuel_Neuer=df.loc[full_df["Name"]=="Manuel Neuer"].values.tolist() #Goal Keeper

De_Gea=df.loc[full_df["Name"]=="De Gea"].values.tolist()       #Goal Keeper

# %%
#Backwards

Toby_Alderweireld = df.loc[full_df["Name"]=="Toby Alderweireld"].values.tolist()  #CB (Center Backward)

David_Luiz = df.loc[full_df["Name"]=="David Luiz"].values.tolist()        #CB (Center Backward)

# %%
CR=kmeans_model.predict(Cristiano_Ronaldo)
LM=kmeans_model.predict(Lionel_Messi)
MO=kmeans_model.predict(Mesut_Özil)
SB=kmeans_model.predict(Sergio_Busquets)
TA=kmeans_model.predict(Toby_Alderweireld)
DL=kmeans_model.predict(David_Luiz)
MN=kmeans_model.predict(Manuel_Neuer)
DG=kmeans_model.predict(De_Gea)

print(f"\n Cristiano Ronaldo belongs to label {CR} & Lionel Messi belongs to label {LM} : Forwards")
print(f"\n Mesut Özil belongs to label {MO} & Sergio Busquets belongs to label {SB} : Mid-Feilders")
print(f"\n Toby Alderweireld belongs to label {TA} & David Luiz belongs to label {DL} : Backwards")
print(f"\n Manuel Neuer belongs to label {MN} De Gea belongs to label {DG} : Goal Keepers ")
# Out:
#  Cristiano Ronaldo belongs to label [0] & Lionel Messi belongs to label [0] : Forwards
#
#  Mesut Özil belongs to label [0] & Sergio Busquets belongs to label [1] : Mid-Feilders
#
#  Toby Alderweireld belongs to label [1] & David Luiz belongs to label [1] : Backwards
#
#  Manuel Neuer belongs to label [2] De Gea belongs to label [2] : Goal Keepers

# %% [markdown]
# #### You must be thinking that when all the Forward players,Backward players & Goal keepers are falling under same labels then why are the Mid players falling under different category ,

# %% [markdown]
# This is because there are two types of mid players :
#
# 1.Mid-forwards : They have the skill set to play mid as well as forwards; CAM (Center Attacking Midfeilder)
#
# 2.Mid-backwards : They have the skill set to play mid as well as backwards ; CDM (Center Defending Midfeilder)

# %% [markdown]
#  That's the reason why :
#
# Mesut Özil (CAM) falls under the label :1 which consists all the forward players
#
# Sergio Busquets (CDM) falls under the label :2 which consists all the backward players
